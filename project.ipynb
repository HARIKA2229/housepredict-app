# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('house_price_regression_dataset.csv')
data.head()
# Out:
#    Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0            1360             2              1        1981  0.599637
# 1            4272             3              3        2016  4.753014
# 2            3592             1              2        2016  3.634823
# 3             966             1              2        1977  2.730667
# 4            4926             2              1        1993  4.699073
#
#    Garage_Size  Neighborhood_Quality   House_Price
# 0            0                     5  2.623829e+05
# 1            1                     6  9.852609e+05
# 2            0                     9  7.779774e+05
# 3            1                     8  2.296989e+05
# 4            0                     8  1.041741e+06

# %%
data.shape
# Out:
# (999, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Square_Footage        999 non-null    int64
#  1   Num_Bedrooms          999 non-null    int64
#  2   Num_Bathrooms         999 non-null    int64
#  3   Year_Built            999 non-null    int64
#  4   Lot_Size              999 non-null    float64
#  5   Garage_Size           999 non-null    int64
#  6   Neighborhood_Quality  999 non-null    int64
#  7   House_Price           999 non-null    float64
# dtypes: float64(2), int64(6)
# memory usage: 62.6 KB

# %%
data.isna().sum()
# Out:
# Square_Footage          0
# Num_Bedrooms            0
# Num_Bathrooms           0
# Year_Built              0
# Lot_Size                0
# Garage_Size             0
# Neighborhood_Quality    0
# House_Price             0
# dtype: int64

# %%
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (999, 8)

# %%
sns.countplot(x = data['Num_Bedrooms'], data = data, palette = 'hls')
plt.show()

# %%
sns.countplot(x = data['Num_Bathrooms'], data = data, palette = 'hls')
plt.show()

# %%
data.describe()
# Out:
#        Square_Footage  Num_Bedrooms  Num_Bathrooms   Year_Built    Lot_Size  \
# count      999.000000    999.000000     999.000000   999.000000  999.000000
# mean      2814.968969      2.988989       1.972973  1986.553554    2.777756
# std       1256.062001      1.427920       0.820742    20.642944    1.298511
# min        503.000000      1.000000       1.000000  1950.000000    0.506058
# 25%       1749.000000      2.000000       1.000000  1969.000000    1.664644
# 50%       2862.000000      3.000000       2.000000  1986.000000    2.809324
# 75%       3851.000000      4.000000       3.000000  2004.500000    3.924725
# max       4999.000000      5.000000       3.000000  2022.000000    4.989303
#
#        Garage_Size  Neighborhood_Quality   House_Price
# count   999.000000            999.000000  9.990000e+02
# mean      1.021021              5.618619  6.187372e+05
# std       0.814792              2.886235  2.536648e+05
# min       0.000000              1.000000  1.116269e+05
# 25%       0.000000              3.000000  4.012940e+05
# 50%       1.000000              6.000000  6.279236e+05
# 75%       2.000000              8.000000  8.271421e+05
# max       2.000000             10.000000  1.108237e+06
